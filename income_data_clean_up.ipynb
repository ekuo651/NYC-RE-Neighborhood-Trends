# %%
import pandas as pd
from pathlib import Path
import numpy as np

# %%
# For input to reading files based on year
year = 2009

if year-2000 < 10:
    year_str = f"0{year-2000}"
else: year_str = f"{year-2000}"
        
year_str
# Out:
# '09'

# %%
# Read excel file and skip title and description rows
xls_path = Path(f"Data/Income/{year_str}zp33ny.xls")
df_xls = pd.read_excel(xls_path, skiprows=3, index_col=None, na_values=['NA'])
df_xls.head()
# Out:
#   ZIP\ncode [1] Size of adjusted gross income  Number of returns  \
# 0           NaN                           NaN                NaN
# 1           NaN                           NaN               -1.0
# 2             0                           NaN          8859870.0
# 3             0              $1 under $25,000          3555603.0
# 4             0         $25,000 under $50,000          2107465.0
#
#    Number of joint returns  Number with paid preparer's signature  \
# 0                      NaN                                    NaN
# 1                     -2.0                                   -3.0
# 2                2885809.0                              5831350.0
# 3                 496249.0                              2241627.0
# 4                 501518.0                              1342830.0
#
#    Number of exemptions  Number of dependents  Adjusted gross income (AGI)  \
# 0                   NaN                   NaN                          NaN
# 1                  -4.0                  -5.0                         -6.0
# 2            16840512.0             5270429.0                  591058301.0
# 3             5286324.0             1551565.0                   42351360.0
# 4             3897170.0             1195917.0                   76646332.0
#
#   Salaries and wages in AGI Unnamed: 9  ... Alternative minimum tax  \
# 0         Number of returns     Amount  ...       Number of returns
# 1                        -7         -8  ...                     -60
# 2                   7279318  414308145  ...                  466119
# 3                   2519194   29460761  ...                     874
# 4                   1865259   63488214  ...                     734
#
#   Unnamed: 62     Income tax [6] Unnamed: 64 Total tax liability [7]  \
# 0      Amount  Number of returns      Amount       Number of returns
# 1         -61                -62         -63                     -64
# 2     3476047            5964627    81598109                 6641628
# 3         601            1174529      766535                 1749990
# 4        1209            1684304     4328850                 1762100
#
#   Unnamed: 66 Tax due at time of filing [8] Unnamed: 68  \
# 0      Amount             Number of returns      Amount
# 1         -65                           -66         -67
# 2    85640574                       1419456     5803715
# 3     1615697                        449035      258237
# 4     4769972                        251980      354726
#
#    Overpayments refunded [9] Unnamed: 70
# 0          Number of returns      Amount
# 1                        -68         -69
# 2                    6896726    23044299
# 3                    2784252     6008426
# 4                    1809800     5077936
#
# [5 rows x 71 columns]

# %%
# Choose relevant columns
zip_col = df_xls.columns.get_loc('ZIP\ncode [1]')
income_bracket_col = df_xls.columns.get_loc('Size of adjusted gross income')
nbr_returns_col = df_xls.columns.get_loc('Number of returns')
AGI_col = np.where(df_xls.columns.str.contains('Adjusted gross income'))[0][0]
df_xls = df_xls.iloc[:, [zip_col,income_bracket_col,nbr_returns_col,AGI_col]]
df_xls
# Out:
#                                            ZIP\ncode [1]  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 12386  [9]  The amount of overpayments the tax filer ...
# 12387  NOTE: This table presents aggregates of all re...
# 12388  In general, during administrative or Master Fi...
# 12389  Detail may not add to totals because of rounding.
# 12390  SOURCE: IRS, Statistics of Income Division, \n...
#
#       Size of adjusted gross income  Number of returns  \
# 0                               NaN                NaN
# 1                               NaN               -1.0
# 2                               NaN          8859870.0
# 3                  $1 under $25,000          3555603.0
# 4             $25,000 under $50,000          2107465.0
# ...                             ...                ...
# 12386                           NaN                NaN
# 12387                           NaN                NaN
# 12388                           NaN                NaN
# 12389                           NaN                NaN
# 12390                           NaN                NaN
#
#        Adjusted gross income (AGI)
# 0                              NaN
# 1                             -6.0
# 2                      591058301.0
# 3                       42351360.0
# 4                       76646332.0
# ...                            ...
# 12386                          NaN
# 12387                          NaN
# 12388                          NaN
# 12389                          NaN
# 12390                          NaN
#
# [12391 rows x 4 columns]

# %%
# Rename columns for consistency
df_xls.columns=(['ZIP','Income Bracket','Nbr of Returns','Adjusted Gross Income'])
df_xls.head(20)
# Out:
#       ZIP           Income Bracket  Nbr of Returns  Adjusted Gross Income
# 0     NaN                      NaN             NaN                    NaN
# 1     NaN                      NaN            -1.0                   -6.0
# 2       0                      NaN       8859870.0            591058301.0
# 3       0         $1 under $25,000       3555603.0             42351360.0
# 4       0    $25,000 under $50,000       2107465.0             76646332.0
# 5       0    $50,000 under $75,000       1196060.0             73491779.0
# 6       0   $75,000 under $100,000        737127.0             63848720.0
# 7       0  $100,000 under $200,000        942941.0            127927947.0
# 8       0         $200,000 or more        320674.0            206792163.0
# 9     NaN                      NaN             NaN                    NaN
# 10  10001                      NaN         12393.0              1644776.0
# 11  10001         $1 under $25,000          4233.0                48988.0
# 12  10001    $25,000 under $50,000          2573.0                95329.0
# 13  10001    $50,000 under $75,000          1767.0               108677.0
# 14  10001   $75,000 under $100,000          1111.0                95936.0
# 15  10001  $100,000 under $200,000          1562.0               214063.0
# 16  10001         $200,000 or more          1147.0              1081783.0
# 17    NaN                      NaN             NaN                    NaN
# 18  10002                      NaN         44144.0              1652980.0
# 19  10002         $1 under $25,000         26619.0               284909.0

# %%
# Take only the rows where it shows total of each ZIP code
# Step 1: Drop rows where ZIP is null

rows_to_drop = df_xls[df_xls['ZIP'].isnull()].index
df_xls = df_xls.drop(rows_to_drop)
df_xls.head(10)
# Out:
#       ZIP           Income Bracket  Nbr of Returns  Adjusted Gross Income
# 2       0                      NaN       8859870.0            591058301.0
# 3       0         $1 under $25,000       3555603.0             42351360.0
# 4       0    $25,000 under $50,000       2107465.0             76646332.0
# 5       0    $50,000 under $75,000       1196060.0             73491779.0
# 6       0   $75,000 under $100,000        737127.0             63848720.0
# 7       0  $100,000 under $200,000        942941.0            127927947.0
# 8       0         $200,000 or more        320674.0            206792163.0
# 10  10001                      NaN         12393.0              1644776.0
# 11  10001         $1 under $25,000          4233.0                48988.0
# 12  10001    $25,000 under $50,000          2573.0                95329.0

# %%
# Step 2: Drop rows where ZIP is 0
rows_to_drop = df_xls[df_xls['ZIP']==0].index
df_xls = df_xls.drop(rows_to_drop)
df_xls.tail(20)
# Out:
#                                                      ZIP  \
# 12371                                              14905
# 12372                                              14905
# 12373                                              14905
# 12374                                              14905
# 12375                                              14905
# 12376                                              14905
# 12377  ** - Not shown to avoid disclosure of informat...
# 12378  [1] The ZIP Code is based on the 5-digit ZIP c...
# 12379  [2] "Qualified dividends" are ordinary dividen...
# 12380  [3] Includes the Alaskan permanent fund, repor...
# 12381  [4] "Earned income credit" includes both the r...
# 12382  [5] The refundable portion of the "earned inco...
# 12383  [6]  "Income tax" reflects the amount reported...
# 12384  [7] "Total tax liability" differs from "Income...
# 12385  [8] Reflects payments to or withholdings made ...
# 12386  [9]  The amount of overpayments the tax filer ...
# 12387  NOTE: This table presents aggregates of all re...
# 12388  In general, during administrative or Master Fi...
# 12389  Detail may not add to totals because of rounding.
# 12390  SOURCE: IRS, Statistics of Income Division, \n...
#
#                 Income Bracket  Nbr of Returns  Adjusted Gross Income
# 12371         $1 under $25,000          1753.0                20716.0
# 12372    $25,000 under $50,000           947.0                34843.0
# 12373    $50,000 under $75,000           655.0                40418.0
# 12374   $75,000 under $100,000           435.0                37543.0
# 12375  $100,000 under $200,000           519.0                69240.0
# 12376         $200,000 or more           134.0                53091.0
# 12377                      NaN             NaN                    NaN
# 12378                      NaN             NaN                    NaN
# 12379                      NaN             NaN                    NaN
# 12380                      NaN             NaN                    NaN
# 12381                      NaN             NaN                    NaN
# 12382                      NaN             NaN                    NaN
# 12383                      NaN             NaN                    NaN
# 12384                      NaN             NaN                    NaN
# 12385                      NaN             NaN                    NaN
# 12386                      NaN             NaN                    NaN
# 12387                      NaN             NaN                    NaN
# 12388                      NaN             NaN                    NaN
# 12389                      NaN             NaN                    NaN
# 12390                      NaN             NaN                    NaN

# %%
# Step 3: Drop null returns  - this will also drop footer rows which we don't need
rows_to_drop = df_xls[df_xls['Nbr of Returns'].isnull()].index
df_xls = df_xls.drop(rows_to_drop)
df_xls.tail(10)
# Out:
#          ZIP           Income Bracket  Nbr of Returns  Adjusted Gross Income
# 12366  14904   $75,000 under $100,000           405.0                34952.0
# 12367  14904  $100,000 under $200,000           224.0                28999.0
# 12368  14904         $200,000 or more             0.0                    0.0
# 12370  14905                      NaN          4443.0               255851.0
# 12371  14905         $1 under $25,000          1753.0                20716.0
# 12372  14905    $25,000 under $50,000           947.0                34843.0
# 12373  14905    $50,000 under $75,000           655.0                40418.0
# 12374  14905   $75,000 under $100,000           435.0                37543.0
# 12375  14905  $100,000 under $200,000           519.0                69240.0
# 12376  14905         $200,000 or more           134.0                53091.0

# %%
# Add average income column and year
df_xls['Average_Income'] = df_xls['Adjusted Gross Income'] / df_xls['Nbr of Returns']
df_xls['Year'] = year
df_xls
# Out:
#          ZIP           Income Bracket  Nbr of Returns  Adjusted Gross Income  \
# 10     10001                      NaN         12393.0              1644776.0
# 11     10001         $1 under $25,000          4233.0                48988.0
# 12     10001    $25,000 under $50,000          2573.0                95329.0
# 13     10001    $50,000 under $75,000          1767.0               108677.0
# 14     10001   $75,000 under $100,000          1111.0                95936.0
# ...      ...                      ...             ...                    ...
# 12372  14905    $25,000 under $50,000           947.0                34843.0
# 12373  14905    $50,000 under $75,000           655.0                40418.0
# 12374  14905   $75,000 under $100,000           435.0                37543.0
# 12375  14905  $100,000 under $200,000           519.0                69240.0
# 12376  14905         $200,000 or more           134.0                53091.0
#
#        Average_Income  Year
# 10         132.718147  2009
# 11          11.572880  2009
# 12          37.049747  2009
# 13          61.503679  2009
# 14          86.351035  2009
# ...               ...   ...
# 12372       36.793031  2009
# 12373       61.706870  2009
# 12374       86.305747  2009
# 12375      133.410405  2009
# 12376      396.201493  2009
#
# [10822 rows x 6 columns]

# %%
# Set ZIP as index
df_xls = df_xls.set_index('ZIP')
df_xls
# Out:
#                 Income Bracket  Nbr of Returns  Adjusted Gross Income  \
# ZIP
# 10001                      NaN         12393.0              1644776.0
# 10001         $1 under $25,000          4233.0                48988.0
# 10001    $25,000 under $50,000          2573.0                95329.0
# 10001    $50,000 under $75,000          1767.0               108677.0
# 10001   $75,000 under $100,000          1111.0                95936.0
# ...                        ...             ...                    ...
# 14905    $25,000 under $50,000           947.0                34843.0
# 14905    $50,000 under $75,000           655.0                40418.0
# 14905   $75,000 under $100,000           435.0                37543.0
# 14905  $100,000 under $200,000           519.0                69240.0
# 14905         $200,000 or more           134.0                53091.0
#
#        Average_Income  Year
# ZIP
# 10001      132.718147  2009
# 10001       11.572880  2009
# 10001       37.049747  2009
# 10001       61.503679  2009
# 10001       86.351035  2009
# ...               ...   ...
# 14905       36.793031  2009
# 14905       61.706870  2009
# 14905       86.305747  2009
# 14905      133.410405  2009
# 14905      396.201493  2009
#
# [10822 rows x 5 columns]
