# %% [markdown]
# # Analysis of Crime, Income, Sales and Development Over Time

# %%
# Import libraries for analysis
import pandas as pd
import numpy as np

# %%
# Import libraries for visualization
# %matplotlib inline
import hvplot.pandas
import plotly.express as px
import matplotlib.pyplot as plt
from panel.interact import interact

# %%
# # Import csv's from individual analysis of the following:

# # Historical Crime 2003-2018
crime_path = 'crime_stats.csv'
crime_df = pd.read_csv(crime_path)
# Historical Income 2004-2016
income_path = 'Data/Income/income_data.csv'
income_df = pd.read_csv(income_path)
# # Historical Sales 2003-2018
sales_path = 'Historic_Sales_Analysis/sales_stats.csv'
sales_df = pd.read_csv(sales_path)
# Historical Development 2000-2019
dev_path = 'dev_df.csv'
dev_df =  pd.read_csv(dev_path)

# %%
# Out:
#   Neighborhood  last_income  avg_pct_change  pct_change_3yr  comparison_3yr  \
# 0         1021   256.526464          0.0762          0.0724         -0.0038
# 1         1026   259.148148          0.0395          0.0205         -0.0190
# 2         3004    43.070362          0.0190          0.0193          0.0003
# 3         3019    89.128119          0.0650          0.0815          0.0165
# 4  AIRPORT JFK    47.046511          0.0078          0.0151          0.0073
#
#    pct_change_5yr  comparison_5yr
# 0          0.0691         -0.0071
# 1          0.0253         -0.0142
# 2          0.0163         -0.0027
# 3          0.0755          0.0105
# 4          0.0162          0.0084

# %% [markdown]
# ## Ranking Metrics

# %%
# adding ranking metrics to crime_df

# %%
# adding ranking metrics to income_df
new_income_columns = ['neighborhood',
                     'last_income',
                     'avg_pct_change',
                     'pct_change_3yr',
                     'comparison_3yr',
                     'pct_change_5yr',
                     'comparison_5yr']
income_df.columns = new_income_columns
income_df.set_index(['neighborhood'], inplace=True)
income_df['current_rank']=income_df['last_income'].rank(ascending=False)
income_df['avg_change_rank']=income_df['avg_pct_change'].rank(ascending=False)
income_df['growth_3yr_rank']=income_df['comparison_3yr'].rank(ascending=False)
income_df['growth_5yr_rank']=income_df['comparison_5yr'].rank(ascending=False)
income_df.head()
# Out:
#               last_income  avg_pct_change  pct_change_3yr  comparison_3yr  \
# neighborhood
# 1021           256.526464          0.0762          0.0724         -0.0038
# 1026           259.148148          0.0395          0.0205         -0.0190
# 3004            43.070362          0.0190          0.0193          0.0003
# 3019            89.128119          0.0650          0.0815          0.0165
# AIRPORT JFK     47.046511          0.0078          0.0151          0.0073
#
#               pct_change_5yr  comparison_5yr  current_rank  avg_change_rank  \
# neighborhood
# 1021                  0.0691         -0.0071          25.0              3.0
# 1026                  0.0253         -0.0142          24.0             63.0
# 3004                  0.0163         -0.0027         179.0            166.5
# 3019                  0.0755          0.0105          55.0             10.0
# AIRPORT JFK           0.0162          0.0084         159.0            205.0
#
#               growth_3yr_rank  growth_5yr_rank
# neighborhood
# 1021                    163.0            199.0
# 1026                    183.0            205.0
# 3004                    151.0            185.5
# 3019                     17.0             25.0
# AIRPORT JFK             100.0             49.0

# %%
# adding ranking metrics to sales_df

new_sales_columns = ['neighborhood',
                     'avg_yearly_sales',
                     'avg_pct_change',
                     'pct_change_3yr',
                     'comparison_3yr',
                     'pct_change_5yr',
                     'comparison_5yr']
sales_df.columns = new_sales_columns
sales_df.set_index(['neighborhood'], inplace=True)
sales_df['current_rank']=sales_df['avg_yearly_sales'].rank(ascending=False)
sales_df['avg_change_rank']=sales_df['avg_pct_change'].rank(ascending=False)
sales_df['growth_3yr_rank']=sales_df['comparison_3yr'].rank(ascending=False)
sales_df['growth_5yr_rank']=sales_df['comparison_5yr'].rank(ascending=False)
sales_df.head()
# Out:
#                          avg_yearly_sales  avg_pct_change  pct_change_3yr  \
# neighborhood
# MIDTOWN WEST                 6.054405e+09          0.3036          0.0389
# UPPER EAST SIDE (59-79)      4.235901e+09          0.0831         -0.0774
# MIDTOWN CBD                  3.705496e+09          0.2531         -0.0645
# UPPER WEST SIDE (59-79)      3.279761e+09          0.1025          0.0332
# UPPER EAST SIDE (79-96)      2.897718e+09          0.0642         -0.0251
#
#                          comparison_3yr  pct_change_5yr  comparison_5yr  \
# neighborhood
# MIDTOWN WEST                    -0.2647          0.1308         -0.1728
# UPPER EAST SIDE (59-79)         -0.1605          0.0112         -0.0719
# MIDTOWN CBD                     -0.3176         -0.0884         -0.3415
# UPPER WEST SIDE (59-79)         -0.0693          0.0963         -0.0062
# UPPER EAST SIDE (79-96)         -0.0893          0.0421         -0.0221
#
#                          current_rank  avg_change_rank  growth_3yr_rank  \
# neighborhood
# MIDTOWN WEST                      1.0             37.0            176.0
# UPPER EAST SIDE (59-79)           2.0            128.5            150.0
# MIDTOWN CBD                       3.0             48.0            181.0
# UPPER WEST SIDE (59-79)           4.0            111.0            113.0
# UPPER EAST SIDE (79-96)           5.0            157.0            124.0
#
#                          growth_5yr_rank
# neighborhood
# MIDTOWN WEST                       179.0
# UPPER EAST SIDE (59-79)            145.0
# MIDTOWN CBD                        191.0
# UPPER WEST SIDE (59-79)            120.0
# UPPER EAST SIDE (79-96)            130.0

# %%
# adding ranking metrics to development_df
new_dev_columns = ['neighborhood',
                     'cumulative_sum',
                     'avg_pct_change',
                     'pct_change_3yr',
                     'comparison_3yr',
                     'pct_change_5yr',
                     'comparison_5yr']
dev_df.columns = new_dev_columns
dev_df.set_index(['neighborhood'], inplace=True)
dev_df['current_rank']=dev_df['cumulative_sum'].rank(ascending=False)
dev_df['avg_change_rank']=dev_df['avg_pct_change'].rank(ascending=False)
dev_df['growth_3yr_rank']=dev_df['comparison_3yr'].rank(ascending=False)
dev_df['growth_5yr_rank']=dev_df['comparison_5yr'].rank(ascending=False)
dev_df.head()
# Out:
#                          cumulative_sum  avg_pct_change  pct_change_3yr  \
# neighborhood
# MIDTOWN WEST               1.384959e+10          0.2515          0.1094
# MIDTOWN CBD                1.209472e+10        139.3866          0.1198
# UPPER EAST SIDE (59-79)    6.525430e+09        147.6482          0.0966
# FASHION                    5.149296e+09          0.2746          0.1110
# FINANCIAL                  4.768688e+09          0.1909          0.0985
#
#                          comparison_3yr  pct_change_5yr  comparison_5yr  \
# neighborhood
# MIDTOWN WEST                    -0.1421           0.125         -0.1265
# MIDTOWN CBD                   -139.2668           0.119       -139.2676
# UPPER EAST SIDE (59-79)       -147.5516           0.104       -147.5442
# FASHION                         -0.1636           0.120         -0.1546
# FINANCIAL                       -0.0924           0.141         -0.0499
#
#                          current_rank  avg_change_rank  growth_3yr_rank  \
# neighborhood
# MIDTOWN WEST                      1.0            133.0             69.0
# MIDTOWN CBD                       2.0              2.0            186.0
# UPPER EAST SIDE (59-79)           3.0              1.0            187.0
# FASHION                           4.0            106.5             89.0
# FINANCIAL                         5.0            174.0             28.0
#
#                          growth_5yr_rank
# neighborhood
# MIDTOWN WEST                        72.0
# MIDTOWN CBD                        186.0
# UPPER EAST SIDE (59-79)            187.0
# FASHION                            100.0
# FINANCIAL                           12.0

# %% [markdown]
# ## Present Day Ranking of Neighborhoods

# %%
# create dataframe to contain rankings by crime, income, sales, development

current_ranking = pd.concat([income_df['current_rank'], sales_df['current_rank'], dev_df['current_rank']], 
                            axis='columns', 
                            join = 'inner')
current_rank_columns = ['income_rank', 'avg_sales_rank','cum_development_rank']
current_ranking.columns = current_rank_columns
len(current_ranking)
# Out:
# 184

# %%
current_ranking.head(50)
# Out:
#                           income_rank  avg_sales_rank  cum_development_rank
# neighborhood
# AIRPORT LA GUARDIA              166.0           200.0                 183.0
# ALPHABET CITY                    34.0            77.0                  83.0
# ASTORIA                          76.0            27.0                  30.0
# BATH BEACH                       89.0           110.0                 142.0
# BATHGATE                        206.0           168.0                 110.0
# BAY RIDGE                        72.0            35.0                  52.0
# BAYCHESTER                      191.0           107.0                 120.0
# BAYSIDE                          97.0            32.0                  40.0
# BEDFORD PARK/NORWOOD            190.0            91.0                  64.0
# BEDFORD STUYVESANT              127.0            21.0                  22.0
# BEECHHURST                       86.0           157.0                 168.0
# BELLEROSE                        95.0           152.0                 166.0
# BELMONT                         195.0           161.0                  93.0
# BENSONHURST                     129.0            59.0                  87.0
# BERGEN BEACH                    102.0           149.0                 170.0
# BOERUM HILL                      44.0            80.0                  47.0
# BOROUGH PARK                    121.0            30.0                  29.0
# BRIARWOOD                       149.0           163.0                 153.0
# BRIGHTON BEACH                  104.0            98.0                 134.0
# BRONX PARK                      198.0           193.0                 171.0
# BRONX-UNKNOWN                   202.0           198.0                 135.0
# BRONXDALE                       181.0           128.0                 109.0
# BROOKLYN HEIGHTS                 47.0            28.0                  36.0
# BROOKLYN-UNKNOWN                 78.0           190.0                 101.0
# BROWNSVILLE                     145.0           131.0                 105.0
# BUSH TERMINAL                   143.0           162.0                  70.0
# BUSHWICK                         92.0            37.0                  35.0
# CANARSIE                        164.0            62.0                  98.0
# CARROLL GARDENS                  45.0            88.0                  67.0
# CASTLE HILL/UNIONPORT           196.0           151.0                 140.0
# CHELSEA                          12.0             6.0                   8.0
# CHINATOWN                        28.0            67.0                  63.0
# CITY ISLAND                     107.0           184.0                 175.0
# CITY ISLAND-PELHAM STRIP         37.0           199.0                 185.0
# CIVIC CENTER                      3.0            26.0                  31.0
# CLINTON                           2.0            24.0                  27.0
# CLINTON HILL                     73.0            66.0                  81.0
# CO-OP CITY                      158.0           197.0                 130.0
# COBBLE HILL                      36.0           112.0                 124.0
# COBBLE HILL-WEST                 42.0           164.0                 165.0
# COLLEGE POINT                   110.0            78.0                  85.0
# CONEY ISLAND                    152.0           119.0                  55.0
# CORONA                          108.0            47.0                  56.0
# COUNTRY CLUB                    119.0           165.0                 177.0
# CROTONA PARK                    203.0           177.0                 103.0
# CROWN HEIGHTS                    98.0            31.0                  28.0
# CYPRESS HILLS                    65.0           113.0                 145.0
# DOUGLASTON                       64.0           129.0                 158.0
# DOWNTOWN-FULTON FERRY            31.0            56.0                  82.0
# DOWNTOWN-FULTON MALL             39.0            58.0                  38.0

# %% [markdown]
# ## Ranking Neighborhoods Based on Growth Rate

# %% [markdown]
# ### Average Increase Across all Years of Available Data

# %%
avg_increase_ranking = pd.concat([income_df['avg_change_rank'], sales_df['avg_change_rank'], dev_df['avg_change_rank']], 
                            axis='columns', 
                            join = 'inner')
avg_increase_rank_columns = ['income_rank', 'sales_rank','development_rank']
avg_increase_ranking.columns = avg_change_rank_columns
len(avg_increase_ranking)
# Out:
# 184

# %%
avg_increase_ranking.head(10)
# Out:
#                       income_rank  sales_rank  development_rank
# neighborhood
# AIRPORT LA GUARDIA          150.0        33.0               6.0
# ALPHABET CITY                44.0        40.0             128.0
# ASTORIA                      69.0       132.0             148.0
# BATH BEACH                   85.0       146.0              53.0
# BATHGATE                    166.5        27.0             164.0
# BAY RIDGE                    60.5       148.0              78.0
# BAYCHESTER                  190.0       108.0             161.0
# BAYSIDE                      74.0       183.0              92.0
# BEDFORD PARK/NORWOOD        171.5        76.0             162.0
# BEDFORD STUYVESANT           48.5       133.0             140.0

# %% [markdown]
# ### Growth in the last 5 Years in Comparison to Average Growth Rate

# %%
growth_5yr_ranking = pd.concat([income_df['growth_5yr_rank'], sales_df['growth_5yr_rank'], dev_df['growth_5yr_rank']], 
                            axis='columns', 
                            join = 'inner')
growth_5yr_rank_columns = ['income_rank', 'sales_rank','development_rank']
growth_5yr_ranking.columns = growth_5yr_rank_columns
len(growth_5yr_ranking)
# Out:
# 184

# %%
growth_5yr_ranking.head(50)
# Out:
#                           income_rank  sales_rank  development_rank
# neighborhood
# AIRPORT LA GUARDIA               34.5       146.0             182.0
# ALPHABET CITY                   189.0       151.0             101.5
# ASTORIA                          59.0       131.0              70.0
# BATH BEACH                      100.5        93.0             148.0
# BATHGATE                        168.0       194.0              52.5
# BAY RIDGE                        63.0        44.0             129.0
# BAYCHESTER                      164.0        61.0              83.0
# BAYSIDE                         180.0        83.0              81.0
# BEDFORD PARK/NORWOOD            151.5        53.0              44.0
# BEDFORD STUYVESANT               20.0       134.0              31.0
# BEECHHURST                      191.0        98.0              82.0
# BELLEROSE                       151.5        75.0             101.5
# BELMONT                         160.5       155.0              94.0
# BENSONHURST                     112.5       125.0             106.0
# BERGEN BEACH                    157.5        63.5             160.0
# BOERUM HILL                      71.5        72.0             179.0
# BOROUGH PARK                     71.5        88.0             178.0
# BRIARWOOD                       157.5       109.0              32.5
# BRIGHTON BEACH                   91.0       102.0              78.0
# BRONX PARK                      123.0       192.0             173.0
# BRONX-UNKNOWN                   128.0       186.0              86.0
# BRONXDALE                       134.0        70.0             103.5
# BROOKLYN HEIGHTS                 66.5       110.0             117.0
# BROOKLYN-UNKNOWN                 50.0         2.0             166.0
# BROWNSVILLE                      42.5        13.0              19.0
# BUSH TERMINAL                    47.0       198.0               3.0
# BUSHWICK                         21.0       105.5              92.0
# CANARSIE                        141.5        22.0              30.0
# CARROLL GARDENS                  77.0       158.0              26.0
# CASTLE HILL/UNIONPORT           138.0         9.0              46.0
# CHELSEA                           5.0        91.0              13.0
# CHINATOWN                       177.0       176.0             154.0
# CITY ISLAND                      80.5        16.0             165.0
# CITY ISLAND-PELHAM STRIP         55.0       202.0             161.0
# CIVIC CENTER                      2.0       153.0              11.0
# CLINTON                          10.0        87.0              38.0
# CLINTON HILL                     27.0       167.5              76.0
# CO-OP CITY                      183.5       193.0              23.0
# COBBLE HILL                      77.0        36.0              41.0
# COBBLE HILL-WEST                 68.5       180.0               8.0
# COLLEGE POINT                   141.5        71.0              61.0
# CONEY ISLAND                    190.0       188.0             172.0
# CORONA                           68.5        54.0              20.0
# COUNTRY CLUB                    141.5        46.0             175.0
# CROTONA PARK                    151.5       165.0             126.0
# CROWN HEIGHTS                    40.0        84.0             114.0
# CYPRESS HILLS                    47.0        55.0              15.0
# DOUGLASTON                       97.5       141.0              24.0
# DOWNTOWN-FULTON FERRY           103.0       140.0             127.0
# DOWNTOWN-FULTON MALL            111.0       197.0               5.0

# %% [markdown]
# ### Recent Growth in Comparison to Average Growth Rate

# %%
growth_3yr_ranking = pd.concat([income_df['growth_3yr_rank'], sales_df['growth_3yr_rank'], dev_df['growth_3yr_rank']], 
                            axis='columns', 
                            join = 'inner')
growth_3yr_rank_columns = ['income_rank', 'sales_rank','development_rank']
growth_3yr_ranking.columns = growth_3yr_rank_columns
len(growth_3yr_ranking)
# Out:
# 184

# %%
growth_3yr_ranking.head(50)
# Out:
#                           income_rank  sales_rank  development_rank
# neighborhood
# AIRPORT LA GUARDIA               39.5        11.0             182.0
# ALPHABET CITY                   186.0        56.0              98.0
# ASTORIA                          44.0       117.0              76.0
# BATH BEACH                       84.5       109.0             141.0
# BATHGATE                         27.5       179.0              70.0
# BAY RIDGE                       133.5        61.0             116.0
# BAYCHESTER                       84.5        47.0              65.0
# BAYSIDE                         148.0        62.0              82.0
# BEDFORD PARK/NORWOOD             77.5        44.0              56.0
# BEDFORD STUYVESANT               21.0       145.0              42.0
# BEECHHURST                      155.0        92.0              68.0
# BELLEROSE                       130.0        25.0              57.0
# BELMONT                          52.5       147.0              94.0
# BENSONHURST                     128.5        58.0              92.0
# BERGEN BEACH                     88.0        83.0             151.0
# BOERUM HILL                     168.0        52.0             179.0
# BOROUGH PARK                     73.5        74.0             178.0
# BRIARWOOD                       122.5        51.0             152.0
# BRIGHTON BEACH                   54.5       163.0             118.0
# BRONX PARK                       45.0       199.0             171.0
# BRONX-UNKNOWN                    35.0         5.0              79.0
# BRONXDALE                       110.5       141.0              86.0
# BROOKLYN HEIGHTS                158.0       103.0              88.0
# BROOKLYN-UNKNOWN                 66.5         1.0             163.0
# BROWNSVILLE                      16.0       160.0              17.0
# BUSH TERMINAL                    15.0       197.0               2.0
# BUSHWICK                         33.0       157.0             105.0
# CANARSIE                         84.5        88.0              21.0
# CARROLL GARDENS                 160.0       125.0               4.0
# CASTLE HILL/UNIONPORT            92.0       146.0              83.0
# CHELSEA                          62.5        64.0              31.0
# CHINATOWN                       179.0       166.0             149.0
# CITY ISLAND                     117.5        60.0             160.5
# CITY ISLAND-PELHAM STRIP         22.5       202.0             165.0
# CIVIC CENTER                      1.0        39.0              19.0
# CLINTON                           5.0       189.0              30.0
# CLINTON HILL                    120.5       183.0              61.0
# CO-OP CITY                      149.5         6.0              20.0
# COBBLE HILL                     173.0       177.0              77.0
# COBBLE HILL-WEST                159.0       178.0               9.0
# COLLEGE POINT                   109.0        24.0              62.0
# CONEY ISLAND                     98.5       190.0             172.0
# CORONA                           36.0        66.0              43.0
# COUNTRY CLUB                    140.0        38.0             175.0
# CROTONA PARK                     38.0        45.0             126.0
# CROWN HEIGHTS                    62.5       132.0              97.0
# CYPRESS HILLS                   126.5       127.0               8.0
# DOUGLASTON                       31.5        67.0              12.0
# DOWNTOWN-FULTON FERRY           182.0        14.0             117.0
# DOWNTOWN-FULTON MALL            181.0       195.0             109.0
